# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import torch
from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.0+cu101 _CudaDeviceProperties(name='Tesla P4', major=6, minor=1, total_memory=7611MB, multi_processor_count=20)

# %%
# !git clone https://github.com/btbph/yolov3  # clone
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 8910, done.
# remote: Total 8910 (delta 0), reused 0 (delta 0), pack-reused 8910
# Receiving objects: 100% (8910/8910), 7.00 MiB | 9.60 MiB/s, done.
# Resolving deltas: 100% (6152/6152), done.

# %% [markdown]
# # New Section

# %%
 # !git clone https://github.com/eriklindernoren /PyTorch-YOLOv3
# Out:
# Cloning into '/PyTorch-YOLOv3'...
# remote: Not Found
# fatal: repository 'https://github.com/eriklindernoren/' not found

# %%
# !ls /content/drive/My\ Drive/yolo/
# Out:
# ls: cannot access '/content/drive/My Drive/yolo/': No such file or directory

# %%
# %cd /content/drive/My\ Drive/yolov3-master
# !ls
# Out:
# /content/drive/My Drive/yolov3-master
# cfg	    models.py	      results.png      train_batch0.png  yolov3
# data	    output	      results.txt      train.py
# detect.py   __pycache__       runs	       tutorial.ipynb
# Dockerfile  README.md	      test_batch0.png  utils
# LICENSE     requirements.txt  test.py	       weights

# %%
# !ls /content/drive/My\ Drive/dataset/
# !python train.py --help
#/content/drive/My\ Drive/yolov3/weights/last.pt
#--img-size 608
#/content/drive/My\ Drive/yolov3/weights/backup70.pt 
#/content/drive/My\ Drive/yolov3-master/weights/best.pt
#/content/drive/My\ Drive/yolov3-master/weights/last.pt
# Out:
#  classes.txt	      train_set.shapes	'yolo_pytorch(1)(1).ipynb'
#  class_labels.names   train_set.txt	 yolov3.cfg
#  coco.data	      valid		 yolov3-spp3.cfg
#  detect		      valid_set.shapes	 yolov3-spp.cfg
#  resistor.data	      valid_set.txt	 yolov3-tiny.cfg
#  train		      weights
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# usage: train.py [-h] [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--cfg CFG]
#                 [--data DATA] [--multi-scale]
#                 [--img-size IMG_SIZE [IMG_SIZE ...]] [--rect] [--resume]
#                 [--nosave] [--notest] [--evolve] [--bucket BUCKET]
#                 [--cache-images] [--weights WEIGHTS] [--name NAME]
#                 [--device DEVICE] [--adam] [--single-cls]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --epochs EPOCHS
#   --batch-size BATCH_SIZE
#   --cfg CFG             *.cfg path
#   --data DATA           *.data path
# ...

# %%
# Train Yolo
#!python train.py --data /content/drive/My\ Drive/yolo_pytorch/resistor.data --cfg /content/drive/My\ Drive/dataset/yolov3-tiny.cfg --weights '' --epochs 80
# !ls /content/drive/My\ Drive/dataset/
# !python train.py --batch-size 1 --data /content/drive/My\ Drive/dataset/resistor.data  --cfg /content/drive/My\ Drive/dataset/yolov3.cfg  --weights /content/drive/My\ Drive/yolov3-master/weights/last.pt --epochs 650
# !python3 -c "from utils import utils; utils.plot_results()"  # plot training results
Image(filename='results.png', width=800)
# Out:
#  classes.txt	      train_set.shapes	'yolo_pytorch(1)(1).ipynb'
#  class_labels.names   train_set.txt	 yolov3.cfg
#  coco.data	      valid		 yolov3-spp3.cfg
#  detect		      valid_set.shapes	 yolov3-spp.cfg
#  resistor.data	      valid_set.txt	 yolov3-tiny.cfg
#  train		      weights		 yolov4.cfg
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Namespace(accumulate=4, adam=False, batch_size=1, bucket='', cache_images=False, cfg='/content/drive/My Drive/dataset/yolov3.cfg', data='/content/drive/My Drive/dataset/resistor.data', device='', epochs=650, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='/content/drive/My Drive/yolov3-master/weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P4', total_memory=7611MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# ...

# %%
4/zwFk0rlHyrpVgCdc4myeuN2AdBBZUbLk51QkxgtRgIn2hZw7fzhXYQ0

# %%
# Detect Yolo
# !python detect.py --conf-thres 0.3 --cfg /content/drive/My\ Drive/dataset/yolov3.cfg --weights /content/drive/My\ Drive/yolov3-master/weights/last.pt --source /content/drive/My\ Drive/dataset/detect
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='/content/drive/My Drive/dataset/yolov3.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/coco.names', output='output', save_txt=False, source='/content/drive/My Drive/dataset/detect', view_img=False, weights='/content/drive/My Drive/yolov3-master/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 222 layers, 6.15237e+07 parameters, 6.15237e+07 gradients
# image 1/97 /content/drive/My Drive/dataset/detect/1039.jpg: 384x512 4 resistors, Done. (0.017s)
# image 2/97 /content/drive/My Drive/dataset/detect/1042.jpg: 384x512 2 resistors, Done. (0.017s)
# image 3/97 /content/drive/My Drive/dataset/detect/1050.jpg: 384x512 2 resistors, Done. (0.017s)
# image 4/97 /content/drive/My Drive/dataset/detect/1058.jpg: 512x384 5 resistors, Done. (0.017s)
# ...

# %%
# !python3 -c "from utils import utils; utils.plot_results()"  # plot training results
Image(filename='results.png', width=800)

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# !ls /content/drive/My\ Drive/yolov3/output
# Out:
# 4.jpg

# %% [markdown]
# 4/zwFk0rlHyrpVgCdc4myeuN2AdBBZUbLk51QkxgtRgIn2hZw7fzhXYQ0
